# %% [markdown]
# # Javascript Arrays
#
# JavaScript array is an object that represents a collection of similar type of elements example:
#
# ```
# const subjects = ["English", "Hindi", "Computer"];
# ```
# An array can hold many values under a single name, and you can access the values by referring to an index number.

# %% [markdown]
# # Creating an Array
#
# Using an array literal is the easiest way to create a JavaScript Array.
#
# Syntax:
# ```
# const array_name = [item1, item2, ...];
# ```
# *   It is a common practice to declare arrays with the const keyword.
# *   Spaces and line breaks are not important. A declaration can span multiple lines
# *   We can also create an array, and then provide the elements
#
# Example demonstrating all the 3 points:
# ```
# const cars = [];
# cars[0]= "Saab";
# cars[1]= "Volvo";
# cars[2]= "BMW";
# ```

# %% [markdown]
# ## Methods to create arrays

# %% [markdown]
# ### Method 1
#
# ```
# var fruits = ['Apple', 'Banana'];
# console.log(fruits) // [ 'Apple', 'Banana' ]
# ```

# %% [markdown]
# ### Method 2
#
# ```
# var msgArray = [];
# msgArray[0] = 'Hello';
# console.log(msgArray) //  [ 'Hello' ]
# ```

# %% [markdown]
# ### Method 3
#
# ```
# var array = new Array('Hello');
# console.log(array) // [ 'Hello' ]
# ```

# %% [markdown]
# ### Method 4
#
# ```
# var another = Array.of(1, 2, 3);
# console.log(another) // [ 1, 2, 3 ]
# ```

# %% [markdown]
# ### Method 5
#
# ```
# var b = arrayMaker({7: 1}, {2: 3});
#
# function arrayMaker(n) {
#   console.log(n);
#   if (n !== typeof Array) {
#     return Array.prototype.slice.call(arguments);
#   }
# }
#
# console.log(b) //  [ { '7': 1 }, { '2': 3 } ]
# ```

# %% [markdown]
# # Operations on arrays

# %% [markdown]
# ## Accessing Array Elements
#
# We access an array element by referring to the index number. Array indexes start with 0. [0] is the first element. [1] is the second element.
#
# ```
# const movies = ["Bollywood", "Hollywood", "Tollywood"];
# let movie = movies[0];
# ```

# %% [markdown]
# ## Changing an Array Element
# This statement changes the value of the required element in the array:
#
# Example:
# ```
# const alphabets = ["p", "l", "x"];
# alphabets[0] = "n";
# ```

# %% [markdown]
# ## Access the Full Array
# With JavaScript, the full array can be accessed by referring to the array name:
#
# Example:
# ```
# const movies = ["Bollywood", "Hollywood", "Tollywood"];
# document.getElementById("demo").innerHTML = movies;
# ```

# %% [markdown]
# ## The length Property
#
# The length property of an array returns the length of an array (the number of array elements). The length property is always one more than the highest array index.
#
# Example:
#
# ```
# const fruits = ["Banana", "Orange", "Apple", "Mango"];
# let length = fruits.length;
# ```

# %% [markdown]
# ## Accessing the First and Last Array Element
#
# ```
# const fruits = ["Banana", "Orange", "Apple", "Mango"];
# let fruit = fruits[0];
# let fruit = fruits[fruits.length - 1];
# ```

# %% [markdown]
# # Arrays and Objects
#
# In JavaScript, arrays use numbered indexes and objects use named indexes. Arrays are a special kind of objects, with numbered indexes. JavaScript does not support associative arrays.
# We use objects when we want the element names to be strings (text) and arrays when we want the element names to be numbers.
#
# *  We can have variables of different types in the same Array. We can have objects or functions or an array in an Array

# %% [markdown]
# # Methods in arrays
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Sorting and operations in Arrays

# %% [markdown]
# ## Sorting an Array
# The sort() method sorts an array alphabetically:
#
# Example:
#
# ```
# const fruits = ["Banana", "Orange", "Apple", "Mango"];
# fruits.sort();
# ```

# %% [markdown]
# ##Reversing an Array
# The reverse() method reverses the elements in an array. We can use it to sort an array in descending order:
#
# Example:
#
# ```
# const fruits = ["Banana", "Orange", "Apple", "Mango"];
# fruits.sort();
# fruits.reverse();
# ```

# %% [markdown]
# ##Numeric Sort
# By default, the sort() function sorts values as strings. This works well for strings ("Apple" comes before "Banana").
#
# However, if numbers are sorted as strings, "25" is bigger than "100", because "2" is bigger than "1". Because of this, the sort() method will produce incorrect result when sorting numbers. This can be fixed by providing a compare function:
#
# Example:
# ```
# const points = [40, 100, 1, 5, 25, 10];
# points.sort(function(a, b){return a - b});
# ```

# %% [markdown]
# ## Sorting an Array in Random Order
# Example:
#
# ```
# const points = [40, 100, 1, 5, 25, 10];
# points.sort(function(a, b){return 0.5 - Math.random()});
# ```

# %% [markdown]
# ## Finding the Highest (or Lowest) Array Value
#
# There are no built-in functions for finding the max or min value in an array. However, after you have sorted an array, you can use the index to obtain the highest and lowest values.
#
# **Sorting ascending:**
#
# ```
# const points = [40, 100, 1, 5, 25, 10];
# points.sort(function(a, b){return a - b});
# // now points[0] contains the lowest value
# // and points[points.length-1] contains the highest value
# ```
#
# **Sorting descending:**
#
#
# ```
# const points = [40, 100, 1, 5, 25, 10];
# points.sort(function(a, b){return b - a});
# // now points[0] contains the highest value
# // and points[points.length-1] contains the lowest value
# ```

# %% [markdown]
# # Array Iteration and its methods
#
# Array iteration methods perform some operation on each element of array. There are some different examples of Array iteration methods are given below.

# %% [markdown]
# ##Array.forEach() function:
# The array.forEach() function calls the provided function(a callback function) once for each element of the array. The provided function is user defined, it can perform any kind of operation on array.
#
# Syntax:
# ```
# array.forEach(function callback(value, index, array){
# }[ThisArgument]);
#
# ```
#
# Parameters: This function accepts three parameters as mentioned above and described below:
#
# *   value: This is the current value being processed by the function.
# *   index: Item index is the index of the current element which was being processed by the function.
# *   array: The array on which the .forEach() function was called.

# %% [markdown]
# ##Array.some() function:
# The array.some() function check whether at least one of the elements of the array satisfies the condition checked by the argument function.
#
# Syntax:
#
# ```
# array.some(arg_function(value, index, array), thisArg);
# ```
#
# Parameters: This function accepts three parameters as mentioned above and described below:
#
#
# *   value: This is the current value being processed by the function.
# *   index: Item index is the index of the current element which was being processed by the function.
# *   array: The array on which the .some() function was called.

# %% [markdown]
# ## Array.map() function:
# The array.map() function creates an array from calling a specific function on each item in the parent array and it does not change the value or element of array.
#
# Syntax:
#
# ```
# array.map(function(value, index, array){
# }[ThisArgument]);
# ```
#
# Parameters: This function accepts three parameters as mentioned above and described below:
#
# *   value: This is the current value being processed by the function.
# *   index: Item index is the index of the current element which was being processed by the function.
# *   array: The array on which the .map() function was called.

# %% [markdown]
# # Questions on Arrays in Javascript
#
# 1. Name two ways to dynamically add the value “bar” to the array “foo”
#
# ```
# foo.push("bar")
#
# foo[foo.length] = "bar";
# ```
#
# 2. Of what JavaScript type is an Array?
#
# Object
#
# 3. What property tells you the length of a JavaScript array?
#
# The “length” property
#
# 4. If the array “foo” has a length of 10, what is the index of the first element in the array?
#
# 0
#
# 5. If the array “foo” has a length of 10, what is the index of the last element in the array?
#
# 9
#
#
# 6. What is the syntax you would use to assign the first element in the array “foo” to the variable “bar”?
#
# ```
# var bar = foo[0];
# ```
# 7. True of False: An element in a JavaScript array can be another array
#
# True
#
#
# 8. Given the following line of code, what is the length of the array “foo”?
# ```
# var foo = [];
# ```
# 0
#
# 9. What does the array.shift() method do, and what does it return?
#
# It removes the first element from the array and returns that element
#
#
# 10. Given the following line of code, what would be the output of the console?
# ```
# var foo = new Array(3);
# console.log(foo);
# ```
#
# [undefined, undefined, undefined]
#
# 11. Numerical and alphabetical sorting code snippet.
#
#
# ```
# <button onclick="myFunction1()">Sort Alphabetically</button>
# <button onclick="myFunction2()">Sort Numerically</button>
#
# <p id="demo"></p>
#
# <script>
# const points = [40, 100, 1, 5, 25, 10];
# document.getElementById("demo").innerHTML = points;
#
# function myFunction1() {
#   points.sort();
#   document.getElementById("demo").innerHTML = points;
# }
#
# function myFunction2() {
#   points.sort(function(a, b){return a - b});
#   document.getElementById("demo").innerHTML = points;
# }
# </script>
# ```
