# %% [markdown]
# # Interacting with Web with Javascript
#
# JavaScript is a programming language we can use to make a website interactive. When we search something on Google or click a link, our website changes — that’s what JavaScript allows us to do. Javascript allows us to make our website really interactive and develop it into a user-friendly interface. Here in this tutorial, we will see a few examples of JS code that will help improve our understanding of interacting with web.

# %% [markdown]
# # What do we mean by Interacting with web with JS?
#
# A normal web page—just regular HTML and CSS—isn’t very responsive. About the only interaction visitors have with the page is clicking a link to load a new page. JavaScript is a programming language that lets you supercharge your HTML with animation, interactivity, and dynamic visual effects. It can also make a web page more responsive to visitors by supplying immediate feedback. For example, a JavaScript-powered shopping cart can instantly display the total cost of your purchase, with tax and shipping, the moment a visitor selects a product to buy; or JavaScript can produce an error message immediately after someone attempts to submit a web form that’s missing information.
#
# JavaScript’s main selling point is immediacy. It lets web pages respond instantly to your visitors’ actions: clicking a link, filling out a form, or merely moving the mouse around the screen. JavaScript doesn’t suffer from the frustrating delay associated with “server-side” interactive programming languages like PHP, which require that a web browser communicate with a remote web server—in other words, JavaScript doesn’t rely on constantly loading and reloading pages. It lets you create pages that look like and respond with the immediacy of a desktop program.
#
# If you’ve visited Google Maps, you’ve seen JavaScript in action. Google Maps lets you zoom in on a map to get a detailed view of streets and zoom out to get a birds-eye view of how to get across town, the state, or the nation, all from the same web page. While there have been lots of map sites before Google, they always required loading a new web page every time you changed a view (a usually slow process).
#
# The JavaScript programs you create can range from the really simple (such as popping up a new browser window with a web page in it) to full-blown “web applications,” such as Google Docs, which let you edit documents, build spreadsheets, and create presentations using your web browser—all as though the program were running on your computer.

# %% [markdown]
# # Some main JS Codes
#
# We will be creating few basic things here that could be used in many different web pages.
#
# 1. Timer
# 2. Hamburger Menu
# 3. Regex

# %% [markdown]
# # Timer
#
# Timer is something that is used in multiple websites and is a basic implementation of JavaScript.

# %% [markdown]
# ##Various functionalities that we will include in order to make the timer:
#
# 1. A button that will display a pop-up asking us how much time we need to set.
# 2. A Play and Pause button that will change as and when Timer is started or stopped. It will also change its color on starting and stopping.
# 3. Time decreasing as the timer is operating.

# %% [markdown]
# ##Example:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Javascript functions to be used in this timer.
#
# 1.
# ```
#     let minutes = document.querySelector(".minutes");
#     let seconds = document.querySelector(".seconds");
#     let toggle = document.querySelector(".toggle");
#     let reset = document.querySelector(".reset");
#
#     let total_seconds_left = 0;
#     let intervalId =null;
# ```
# 2.
# ```
# reset.addEventListener("click", ()=>{
#         let inputime = prompt("For how many minutes you would like to set up the timer");
#         if(inputime<60)
#         {   total_seconds_left = inputime *60;
#             updateTime();   }
#     });
# ```
# 3.
# ```
# function updateTime()
#     {  let min = Math.floor(total_seconds_left /60);
#         let sec = total_seconds_left % 60;
#         minutes.textContent = min.toString().padStart(2,"0") ;
#         seconds.textContent = sec.toString().padStart(2,"0");
#     }
# ```
#
# 4.
# ```
#   toggle.addEventListener("click", ()=>{
#         if(intervalId ==null)
#         {
#             startTimer();
#         }
#         else
#         {
#             stopTimer();
#         }
#     });
#
#  ```
#
# 5.
# ```
# function manageToggle()
# {
#     if(intervalId==null)
#     {
#                    //play, green
#         toggle.innerHTML = '<span class="material-icons">play_arrow</span>';
#         toggle.classList.add("start");
#         toggle.classList.remove("stop");
#
#     }
#     else
#     {
#           // pause, red
#
#         toggle.innerHTML = '<span class="material-icons">pause</span>';
#         toggle.classList.add("stop");
#         toggle.classList.remove("start");
#     }
# }
# ```
# 6.
# ```
# function startTimer ()
# {
#
#     if(total_seconds_left ==0)
#     {
#         return;
#     }
#    intervalId  =setInterval(()=>{
#        total_seconds_left--;
#        updateTime();
#        if(total_seconds_left ==0)
#        {
#            stopTimer();
#        }
#
#    }, 1000);
#
#    manageToggle();
# }
# function stopTimer ()
# {
#     clearInterval (intervalId);
#     intervalId =null;
#     manageToggle();
# }
# ```

# %% [markdown]
# ## Task 1: Try to add HTML and CSS code to the above Javascript snippets to make a complete timer file and give the output as given in above example.
#
# Solution.
#
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">;
# <style>
#     .time{font-size:25px}
#     .mybox{
#         background-color: antiquewhite;
#         display:inline-block ;
#         padding: 50px;
#
#     }
#     .time_btn
#     {
#         width: 50px;
#         margin: 10px;
#
#     }
#
#     .start{
#         background-color: green;
#     }
#
#     .stop
#     {
#         background-color: red;
#     }
# </style>
# </head>
# <body>
#     <div class="mybox">
# <span class="time minutes">00</span>
# <span class="time">:</span>
# <span class="time seconds">00</span>
# <button class="time_btn toggle ">
#     <span class="material-icons">
#         play_arrow
#         </span>
# </button>
#
# <button class="time_btn reset">
#     <span class="material-icons">
#     timer
# </span>
# </button>
#     </div>
# </body>
#
# <script>
#     let minutes = document.querySelector(".minutes");
#     let seconds = document.querySelector(".seconds");
#     let toggle = document.querySelector(".toggle");
#     let reset = document.querySelector(".reset");
#
#     let total_seconds_left = 0;
#     let intervalId =null;
#
#
#     reset.addEventListener("click", ()=>{
#         let inputime = prompt("For how many minutes you would like to set up the timer");
#         if(inputime<60)
#         {   total_seconds_left = inputime *60;
#             updateTime();   }
#     });
#     function updateTime()
#     {  let min = Math.floor(total_seconds_left /60);
#         let sec = total_seconds_left % 60;
#         minutes.textContent = min.toString().padStart(2,"0") ;
#         seconds.textContent = sec.toString().padStart(2,"0");
#     }
#
#     toggle.addEventListener("click", ()=>{
#         if(intervalId ==null)
#         {
#             startTimer();
#         }
#         else
#         {
#             stopTimer();
#         }
#
#
#     });
#
# function manageToggle()
# {
#     if(intervalId==null)
#     {
#                    //play, green
#         toggle.innerHTML = '<span class="material-icons">play_arrow</span>';
#         toggle.classList.add("start");
#         toggle.classList.remove("stop");
#
#     }
#     else
#     {
#           // pause, red
#
#         toggle.innerHTML = '<span class="material-icons">pause</span>';
#         toggle.classList.add("stop");
#         toggle.classList.remove("start");
#     }
# }
#
# function startTimer ()
# {
#
#     if(total_seconds_left ==0)
#     {
#         return;
#     }
#    intervalId  =setInterval(()=>{
#        total_seconds_left--;
#        updateTime();
#        if(total_seconds_left ==0)
#        {
#            stopTimer();
#        }
#
#
#    }, 1000);
#
#    manageToggle();
# }
#
# function stopTimer ()
# {
#     clearInterval (intervalId);
#     intervalId =null;
#     manageToggle();
# }
#
# </script>
# </html>
# ```

# %% [markdown]
# # Hamburger menu
#
# Hamburger menu is like a simple table of contents that is being displayed when we click on any particular button on the web page. It is an essential part of almost every website.

# %% [markdown]
# ##Various functionalities that we will include in order to make the menu:
#
# 1. A button, which when clicked will change its color and display the menu.
#
# 2. Each item in the menu list will contain the link to some particluar part of the webpage, which on click will redirect us to that part of the webpage.

# %% [markdown]
# ## Example
#
# This close button will be converted into menu button once the menu is closed and clicking on category 2 option in the menu will take us to category 2 part of the page.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## JavaScript functions to be used in this timer
#
# ```
#     let hamburger = document.querySelector(".hamburger");
#     let dropdownlist = document.querySelector(".dropdownlist");
#     let menub = document.querySelector(".menub");
#     let closeb = document.querySelector(".closeb");
#     hamburger.addEventListener("click", ()=>{
#
#         if(dropdownlist.classList.contains("menu-visible"))
#         {
#
#             dropdownlist.classList.remove("menu-visible");
#             menub.style.display= "block";
#             closeb.style.display = "none";
#         }
#         else
#         {
#             dropdownlist.classList.add("menu-visible");
#             menub.style.display= "none";
#             closeb.style.display = "block";
#
#         }
#
#     });
# ```

# %% [markdown]
# ## Task 2: Try to add HTML and CSS code to the above Javascript snippets to make a complete hamburger menu and give the output as given in above example.
#
# Solution.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link href="https://fonts.googleapis.com/icon?family=Material+Icons&quot;
#     rel="stylesheet">
# <style>
#     .dropdownlist{
#         list-style-type: none;
#         background-color: antiquewhite;
#         display: inline-block;
#         padding: 50px;
#         font-size: 20px;
#         position: absolute;
#         right: 0;
#         z-index: 0;
#         display: none;
#     }
#
#     .menu-visible
#     {
#         display: block;
#     }
#     *{
#         margin-top: 0;
#     }
#     li{
#         margin: 15px;
#     }
#
#     a{
#         text-decoration: none;
#         color: black;
#     }
#     .hamburger{
#         position: absolute;
#         right: 0;
#         z-index: 1;
#     }
#
#     .closeb{
#         display: none;
#     }
# </style>
#
# </head>
#
# <body>
#     <button class="hamburger">
#         <span class="material-icons menub">
#             menu
#             </span>
#             <span class="material-icons closeb">
#                 close
#                 </span>
#     </button>
#  <ul class="dropdownlist">
#      <li> <a href="">Home</a></li>
#      <li> <a href="">Category 1</a></li>
#      <li> <a href="#c2">Category 2</a></li>
#      <li> <a href="">Category 3</a></li>
#  </ul><br>
#  <br><br><br><br><br><br><br><br><br><br><br><br>
#  <br><br><br><br><br><br><br><br><br><br><br><br>
#  <br><br><br><br><br><br><br><br><br><br><br><br>
#  <h1 id="c2"> Category 2</h1>
#  <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Deserunt, iusto velit dolorum sint, harum fugit molestias rem necessitatibus illo aliquid optio. At deserunt omnis culpa quaerat molestiae dolorum natus fuga hic nobis eum nemo, eos debitis cum possimus commodi iste neque velit, harum vitae illum fugiat! Reprehenderit natus obcaecati ipsa?</p>
# <script>
#     let hamburger = document.querySelector(".hamburger");
#     let dropdownlist = document.querySelector(".dropdownlist");
#     let menub = document.querySelector(".menub");
#     let closeb = document.querySelector(".closeb");
#     hamburger.addEventListener("click", ()=>{
#
#         if(dropdownlist.classList.contains("menu-visible"))
#         {
#
#             dropdownlist.classList.remove("menu-visible");
#             menub.style.display= "block";
#             closeb.style.display = "none";
#         }
#         else
#         {
#             dropdownlist.classList.add("menu-visible");
#             menub.style.display= "none";
#             closeb.style.display = "block";
#
#         }
#
#     });
# </script>
# </body>
# </html>
# ```

# %% [markdown]
# # Regex
# Regular expressions are patterns used to match character combinations in strings. In JavaScript, regular expressions are also objects. It is mostly used when we need the user to input values that satisfy a particular condition eg. here we will create a singup page which will request certain things from the user and won't move to the next step until those conditions are satisfied.

# %% [markdown]
# ##Various functionalities that we will include in order to make the sign-up:
#
# 1. It won't allow us to move to the next step until we give the correct name.
#
# 2. It will set a condition on the password as well that it should contain atleast 8 characters and a special character.
#
# 3. The confirm password option should match the original password.

# %% [markdown]
# ## Example
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Javascript functions used to make this
#
#
#
# ```
#     <script type= "text/javascript">
#         var res = "true";
#     function validation(){
#
#         var username = document.getElementById('username').value;
#         var Password = document.getElementById('Password').value;
#         var confirmPassword = document.getElementById('confirm_Password').value;
#
#         var usernamecheck = /^[A-Za-z ]{3,30}$/;
#         var passwordcheck = /^(?=.*[0-9])(?=.*[!@#$%^&*])[a-zA-Z0-9!@#$%^&*]{8,16}$/;
#
#         if(usernamecheck.test(username)){
#             document.getElementById('usernameerror').innerHTML = " ";
#        }
#             else{
#                 document.getElementById('usernameerror').innerHTML = "**Username must be of at least 3 character long and max of 30 characters ";
#                 res = "false";
#                 return res;
#      }
#         if(passwordcheck.test(Password)){
#             document.getElementById('passworderror').innerHTML = " ";
#       }
#             else{
#                 document.getElementById('passworderror').innerHTML = "**Password must be of at least 8 characters and should contain a special character and a numerical value ";
#                 res = "false";
#                 return res;
#        }
#
#         if(Password.match(confirmPassword)){
#             document.getElementById('cpassworderror').innerHTML = " ";
#        }
#             else{
#                 document.getElementById('cpassworderror').innerHTML = "**Does mot match with your password ";
#                 res = "false";
#                 return res;
#        }
#
#
#      }
#
#
#          let addbtn = document.getElementById('button');
#          addbtn.addEventListener("dblclick" , function(){
#             console.log("hoii");
#             //    window.location.href = "Mellowtrips.html";
#             window.open("Mellowtrips.html",'_blank');
#          })
#
#     </script>
# ```

# %% [markdown]
# ## Task 3: Try to add HTML and CSS code to the above Javascript snippets to make the sign up page and give the output as given in above example.
#
# Solution.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link href = "signup.css" rel = "stylesheet">
#     <title>MellowTrips</title>
# </head>
# <body>
#     <div id="login">
#         <div id="login_img">
#
#         </div>
#         <div id="signupform">
#             <img src = "wplogo.png">
#             <h5>MellowTrips</h5>
#             <p>Create an account</p>
#             <form id="myForm" action="#"  onsubmit=" return validation()">
#                 <div class="formgroup">
#                     <label>UserName</label><br>
#                     <input type = "text" id = "username"><br>
#                     <span id = "usernameerror"></span>
#                 </div>
#                 <div class="formgroup">
#                     <label>Password</label><br>
#                     <input type = "text" id = "Password"><br>
#                     <span id = "passworderror"></span>
#                 </div>
#                 <div class="formgroup">
#                     <label>Confirm Password</label><br>
#                     <input type = "text" id = "confirm_Password"><br>
#                     <span id = "cpassworderror"></span>
#                 </div>
#                 <a href = "Mellowtrips.html"><input type = "submit" value = "SignUp" id = "button"></a>
#             </form>
#             <p id = "or">or</p>
#             <div id="google">
#                 <img src="https://w0.peakpx.com/wallpaper/566/744/HD-wallpaper-new-google-g-color-logo.jpg">
#        <button  class="login-with-google-btn" >
#         Sign in with Google
#       </button>
#     </div>
#         </div>
#     </div>
#     <script type= "text/javascript">
#         var res = "true";
#     function validation(){
#
#         var username = document.getElementById('username').value;
#         var Password = document.getElementById('Password').value;
#         var confirmPassword = document.getElementById('confirm_Password').value;
#
#         var usernamecheck = /^[A-Za-z ]{3,30}$/;
#         var passwordcheck = /^(?=.*[0-9])(?=.*[!@#$%^&*])[a-zA-Z0-9!@#$%^&*]{8,16}$/;
#
#         if(usernamecheck.test(username)){
#             document.getElementById('usernameerror').innerHTML = " ";
#        }
#             else{
#                 document.getElementById('usernameerror').innerHTML = "**Username must be of at least 3 character long and max of 30 characters ";
#                 res = "false";
#                 return res;
#      }
#         if(passwordcheck.test(Password)){
#             document.getElementById('passworderror').innerHTML = " ";
#       }
#             else{
#                 document.getElementById('passworderror').innerHTML = "**Password must be of at least 8 characters and should contain a special character and a numerical value ";
#                 res = "false";
#                 return res;
#        }
#
#         if(Password.match(confirmPassword)){
#             document.getElementById('cpassworderror').innerHTML = " ";
#        }
#             else{
#                 document.getElementById('cpassworderror').innerHTML = "**Does mot match with your password ";
#                 res = "false";
#                 return res;
#        }
#
#
#      }
#
#
#          let addbtn = document.getElementById('button');
#          addbtn.addEventListener("dblclick" , function(){
#             console.log("hoii");
#             window.open("Mellowtrips.html",'_blank');
#          })
#
#
#
#     </script>
# </body>
# </html>
# ```
